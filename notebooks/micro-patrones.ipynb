// %% [markdown]
// # Micro-patrones de implementación
//
// En esta práctica veremos, en forma incremental, diversos patrones de implementación. El ejemplo que nos guiará será el mismo para todos los ejercicios.
//
// ---
//
// **¿Qué vamos a aprender?**
//
// Cada bloque introduce un patrón distinto para recorrer y transformar colecciones de datos:
//
// | Bloque | Patrón |
// |--------|--------|
// | 1 | Acumulación |
// | 2a | Conteo |
// | 2b | Existencia |
// | 3 | Filtrado |
// | 4 | Composición simple |
// | 4.5 | Composición con extremos |
// | 5 | Libre — propuesta propia |
//
// ---

// %% [markdown]
// ## El contexto
//
// Tenemos las notas finales de un curso. ¿Qué preguntas le haríamos a esos datos? Propongamos en voz alta.

// %% [markdown]
// *(completamos aquí las preguntas que surjan)*

// %%
double[] notas = { 7.5, 4.0, 9.0, 6.5, 3.0, 8.5, 5.0, 9.5, 6.0, 4.5 };

// %% [markdown]
// ---
//
// ## Bloque 1 - Acumulación (10 minutos)
//
// **Patrón:** recorrer todos los elementos y acumular un resultado parcial.
//
// ### ¿Cómo calculamos el promedio?
//
// > **Pista:** el promedio requiere dos cosas: la suma de todos los elementos y la cantidad de elementos. ¿Cómo obtenés cada una de forma separada? ¿Y si lo hacés en un solo recorrido?

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 2a - Conteo (10 minutos)
//
// **Patrón:** recorrer los elementos aplicando una condición y contar cuántos la cumplen.
//
// ### ¿Cuántos aprobaron?
//
// > **Pista:** ¿cuál es el umbral de aprobación? ¿Qué necesitás incrementar cada vez que un elemento supera ese umbral?

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 2b - Existencia (10 minutos)
//
// **Patrón:** a veces no importa *cuántos* cumplen una condición, sino si *existe al menos uno*. Son preguntas parecidas, pero la estrategia puede ser distinta.
//
// ### ¿Alguno sacó 10?
//
// > **Pista:** una vez que encontrás lo que buscás, ¿tiene sentido seguir recorriendo el resto del array?

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 3 - Filtrado (10 minutos)
//
// **Patrón:** construir una nueva colección que contenga solo los elementos que cumplen una condición.
//
// ### ¿Cómo me quedo solo con las notas de los que desaprobaron?
//
// > **Pista:** necesitás una estructura para guardar los resultados. ¿De qué tamaño la creás? ¿Qué pasa si no sabés de antemano cuántos van a quedar?

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 4 - Composición simple (15 minutos)
//
// **Patrón:** encadenar varias operaciones anteriores para responder una pregunta más compleja.
//
// ### ¿Cuál es el promedio de los alumnos que aprobaron, ignorando al que sacó la nota más alta?
//
// > **Pista:** descomponé el problema en pasos. ¿Qué operaciones de los bloques anteriores podés reutilizar? Un posible orden: filtrar → encontrar el máximo → excluirlo → promediar.

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 4.5 - Composición con extremos (10 minutos)
//
// **Patrón:** filtrar y luego encontrar valores extremos en el resultado.
//
// ### ¿Cuál es la diferencia entre la nota más alta y la más baja entre los que aprobaron?
//
// > **Pista:** primero filtrá los aprobados (ya lo hiciste antes). Sobre esa nueva colección, ¿cómo encontrás el máximo y el mínimo en un solo recorrido?

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Bloque 5 - Propuesta libre (10 minutos)
//
// **Patrón:** ¡el que elijan!
//
// Ahora proponemos y resolvemos, por grupos, algún otro "informe" que querramos obtener a partir de las notas.
//
// > Algunas ideas posibles (solo si no se les ocurre ninguna): ¿cuál es la nota más baja? ¿Cuántos están entre 6 y 8? ¿Cómo se verían las notas ordenadas de mayor a menor?

// %% [markdown]
// *(describir aquí la pregunta que eligieron responder)*

// %%
// código aquí

// %% [markdown]
// ---
//
// ## Cierre - Para pensar
//
// Antes de terminar, algunas preguntas para reflexionar en grupo:
//
// 1. **¿Qué patrones aparecieron más de una vez?** ¿Por qué creés que se repiten?
//
// 2. **¿Cuándo conviene hacer todo en un solo recorrido y cuándo conviene separarlo en varios pasos?** ¿Hay alguna ventaja en uno u otro enfoque?
//
// 3. **¿Qué hubiera cambiado si las notas fueran miles en lugar de diez?** ¿Alguna de tus soluciones tendría problemas?
